# %%
import logging
logging.basicConfig(level=logging.DEBUG)

import serial
import toyplot

import pipecat.device.charger
import pipecat.limit
import pipecat.source.time
import pipecat.storage

import IPython.display

# %%
pipeline = pipecat.device.charger.icharger208b(serial.serial_for_url("/dev/cu.SLAB_USBtoUART", baudrate=128000))
pipeline = pipecat.source.time.timestamp(pipeline)
pipeline = pipecat.limit.timeout(pipeline, timeout=pipecat.quantity(5, pipecat.units.seconds))
pipeline = pipecat.storage.cache(pipeline)

for record in pipeline:
    canvas = toyplot.Canvas()
    axes = canvas.cartesian(grid=(3, 1, 0), label="Battery", ylabel="Voltage (V)")
    axes.plot(pipeline.table[("battery", "voltage")].to(pipecat.units.volt))

    axes = canvas.cartesian(grid=(3, 1, 1), ylabel="Current (A)")
    axes.plot(pipeline.table[("battery", "current")].to(pipecat.units.amp))

    axes = canvas.cartesian(grid=(3, 1, 2), ylabel="Charge (mAH)")
    axes.plot(pipeline.table[("battery", "charge")].to(pipecat.units.milliamp * pipecat.units.hour))
    
    IPython.display.clear_output()
    IPython.display.display_html(canvas)
# Out:
# <div align="center" class="toyplot" id="t8800d2a13cf2436e9d9f5c37290b601c"><svg class="toyplot-canvas-Canvas" height="600px" id="t247be27b65b4487497a0e99e3ecac042" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 600 600" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="ta6aac9df04a24d65961ef9de899cd8d9"><clipPath id="tcd5ed3198fce4b48829f427b6bee0668"><rect height="120.0" width="520.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#tcd5ed3198fce4b48829f427b6bee0668)"><g class="toyplot-mark-Plot" id="t11c20e7875c04099a28f97d5c58888e2" style="fill:none"><g class="toyplot-Series"><path d="M 50.0 150.0 L 50.970873786407772 150.0 L 51.941747572815537 140.
# ...
