# %%
import logging
logging.basicConfig(level=logging.DEBUG)

import datacat.limit
import datacat.source.time
import datacat.storage

# %%
pipeline = datacat.source.time.metronome()
pipeline = datacat.source.add(pipeline, "foo", "bar")
pipeline = datacat.source.time.timestamp(pipeline)
pipeline = datacat.limit.count(pipeline, count=3)
pipeline = datacat.storage.csv(pipeline, "csv-output.csv")

for record in pipeline:
    datacat.dump(record)
# Out:
# foo: bar
# timestamp: 2016-11-30T03:58:47.532802+00:00
#
# foo: bar
# timestamp: 2016-11-30T03:58:48.538147+00:00
# INFO:datacat:Iteration stopped after 3 records.
# foo: bar
# timestamp: 2016-11-30T03:58:49.543481+00:00
